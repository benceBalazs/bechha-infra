# %% [markdown]
# # Base definitions

# %%
import posixpath

# Root path for the project
ROOT_DIR = 'A:/IVADL'

# V3C1 path
V3C1_DIR = posixpath.join(ROOT_DIR, "V3C1-100")

# %%
import os

def get_all_videos(base_dir):
    """
    Get all directories under the given base directory.
    
    :param base_dir: The base directory to search under.
    :return: A list of all directories under the base directory.
    """
    all_dirs = []
    for root, dirs, files in os.walk(base_dir):
        for dir_name in dirs:
            all_dirs.append(dir_name)
        break
    return all_dirs

# %% [markdown]
# # Detect shot boundaries with Transnetv2
# https://github.com/soCzech/TransNetV2/blob/master/inference/transnetv2.py

# %% [markdown]
# ### Detect and generate scenes

# %%
from transnetv2 import TransNetV2
import os
import numpy as np
from PIL import Image

def make_prodictions(video_name):
    video_dir = posixpath.join(V3C1_DIR, video_name)

    # Check if the scenes file already exists
    scenes_full_path = posixpath.join(video_dir, f"{video_name}_scenes.txt")
    if posixpath.isfile(scenes_full_path):
        print(f"The scenes file {scenes_full_path} already exists. Skipping prediction.")
        return

    video_mp4_path = posixpath.join(video_dir, f"{video_name}.mp4")
    video_mov_path = posixpath.join(video_dir, f"{video_name}.mov")
    if posixpath.isfile(video_mp4_path):
        video_full_path = video_mp4_path
    elif posixpath.isfile(video_mov_path):
        video_full_path = video_mov_path
    else:
        raise FileNotFoundError(f"Neither .mp4 nor .mov video file exists for {video_name}.")

    # Predict the scenes in the video
    try:
        video_frames, single_frame_p, all_frame_p = model.predict_video(video_full_path)
    except Exception as e:
        raise RuntimeError(f"Error predicting video: {e}")

    # Convert predictions to a list of scenes
    list_of_scenes = model.predictions_to_scenes(predictions=all_frame_p)

    # Visualize the predictions on the video frames
    pil_image = model.visualize_predictions(
        frames=video_frames, predictions=(single_frame_p, all_frame_p)
    )

    # Save the visualization image (optional)
    visualization_path = posixpath.join(video_dir, f"{video_name}_visualization.png")
    pil_image.save(visualization_path)

    # Write the list of scenes to a file
    np.savetxt(scenes_full_path, list_of_scenes, fmt="%d")

# Specify the paths for weights and video file
weights_dir = posixpath.join(ROOT_DIR, "transnetv2-weights")

# Initialize the TransNetV2 model with the weights directory
model = TransNetV2(weights_dir)

videos = get_all_videos(V3C1_DIR)
for video in videos:
    make_prodictions(video)
# Out:
# The scenes file A:/IVADL/V3C1-100/00100/00100_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00101/00101_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00102/00102_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00103/00103_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00104/00104_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00105/00105_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00106/00106_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00107/00107_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00108/00108_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00109/00109_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00110/00110_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00111/00111_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00112/00112_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00113/00113_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00114/00114_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00115/00115_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00116/00116_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00117/00117_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00118/00118_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00119/00119_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00120/00120_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00121/00121_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00122/00122_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00123/00123_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00124/00124_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00125/00125_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00126/00126_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00127/00127_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00128/00128_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00129/00129_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00130/00130_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00131/00131_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00132/00132_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00133/00133_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00134/00134_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00135/00135_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00136/00136_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00137/00137_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00138/00138_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00139/00139_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00140/00140_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00141/00141_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00142/00142_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00143/00143_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00144/00144_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00145/00145_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00146/00146_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00147/00147_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00148/00148_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00149/00149_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00150/00150_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00151/00151_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00152/00152_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00153/00153_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00154/00154_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00155/00155_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00156/00156_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00157/00157_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00158/00158_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00159/00159_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00160/00160_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00161/00161_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00162/00162_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00163/00163_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00164/00164_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00165/00165_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00166/00166_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00167/00167_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00168/00168_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00169/00169_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00170/00170_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00171/00171_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00172/00172_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00173/00173_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00174/00174_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00175/00175_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00176/00176_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00177/00177_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00178/00178_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00179/00179_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00180/00180_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00181/00181_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00182/00182_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00183/00183_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00184/00184_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00185/00185_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00186/00186_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00187/00187_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00188/00188_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00189/00189_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00190/00190_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00191/00191_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00192/00192_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00193/00193_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00194/00194_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00195/00195_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00196/00196_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00197/00197_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00198/00198_scenes.txt already exists. Skipping prediction.
# The scenes file A:/IVADL/V3C1-100/00199/00199_scenes.txt already exists. Skipping prediction.

# %% [markdown]
# ### Generate Json file of the scenes
# Add additional intervals if the scene is longer than 10 seconds

# %%
import json
import numpy as np
from datetime import timedelta
import subprocess
import re
import posixpath

def get_fps(video_path):
    """
    Get the frames per second (fps) of a video using ffmpeg.
    
    :param video_path: The path to the video file.
    :return: The fps as a float.
    """
    command = [
        'ffmpeg',
        '-i', video_path,
        '-hide_banner'
    ]

    result = subprocess.run(command, stderr=subprocess.PIPE, stdout=subprocess.PIPE)

    # Decode with 'utf-8' and ignore errors
    output = result.stderr.decode('utf-8', errors='ignore')

    # Extract fps using regular expression
    fps_match = re.search(r'(\d+(\.\d+)?) fps', output)
    if fps_match:
        fps = float(fps_match.group(1))
        return fps
    else:
        raise ValueError("FPS not found in ffmpeg output")

def frames_to_timecode(frame_number, fps):
    """Convert frame number to timecode."""
    seconds = frame_number / fps
    timecode = str(timedelta(seconds=seconds)).split(".")[0]
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{timecode}.{milliseconds:03d}"

def format_scenes_to_json(video_name, min_seconds=0):
    video_dir = posixpath.join(V3C1_DIR, video_name)
    scenes_full_path = posixpath.join(video_dir, f"{video_name}_scenes.txt")

    if not posixpath.isfile(scenes_full_path):
        raise FileNotFoundError(f"The scenes file {scenes_full_path} does not exist.")

    video_mp4_path = posixpath.join(video_dir, f"{video_name}.mp4")
    video_mov_path = posixpath.join(video_dir, f"{video_name}.mov")
    if posixpath.isfile(video_mp4_path):
        video_full_path = video_mp4_path
    elif posixpath.isfile(video_mov_path):
        video_full_path = video_mov_path
    else:
        raise FileNotFoundError(f"Neither .mp4 nor .mov video file exists for {video_name}.")

    fps = get_fps(video_full_path)
    min_frames = int(min_seconds * fps) if min_seconds > 0 else 0

    # Load the scenes from the file
    scenes = np.loadtxt(scenes_full_path, dtype=int)
    
    # Ensure scenes are a two-dimensional array
    if scenes.ndim == 1:
        scenes = scenes.reshape(1, -1)

    # Process the intervals
    scene_intervals = []
    additional_intervals = []
    for start_frame, end_frame in scenes:
        # Add 5 additional time steps for the start. Otherwise it can be a problem with switching scenes
        scene_intervals.append(start_frame + 5 if start_frame > 0 else 0)

    # Add the last end_frame to scene_intervals
    scene_intervals.append(scenes[-1, 1])

    if min_frames > 0:
        prev_interval = 0
        for interval in scene_intervals:
            diff = interval - prev_interval

            if diff > min_frames * 1.5:
                # Number of intervals needed
                num_intervals = (diff // min_frames) + 1
                # Step size for even distribution
                step = diff // num_intervals
                additional_intervals.extend(prev_interval + i * step for i in range(1, num_intervals))

            prev_interval = interval

    intervals = sorted(scene_intervals + additional_intervals)
    
    # Prepare the JSON structure
    scenes_json = []

    for index, start_frame in enumerate(intervals[:-1]):
        end_frame = intervals[index + 1] - 1
        scene_data = {
            "frame": f"{video_name}_frame{index+1:04d}.jpg",
            "starting_frame": int(start_frame),
            "ending_frame": int(end_frame),
            "starting_time": frames_to_timecode(start_frame, fps),
            "ending_time": frames_to_timecode(end_frame, fps)
        }
        scenes_json.append(scene_data)

    # Convert the list to a JSON string
    scenes_json_str = json.dumps(scenes_json, indent=2)
    
    # Save the JSON to a file
    json_full_path = posixpath.join(video_dir, f"{video_name}_scenes.json")
    with open(json_full_path, 'w') as json_file:
        json_file.write(scenes_json_str)
    
    return

videos = get_all_videos(V3C1_DIR)
for video in videos:
    format_scenes_to_json(video, min_seconds=10)

# %% [markdown]
# ### Generate keyframe files with FFMPEG

# %%
import ffmpeg
import posixpath

def extract_keyframes(video_name):
    video_dir = posixpath.join(V3C1_DIR, video_name)
    scenes_full_path = posixpath.join(video_dir, f"{video_name}_scenes.json")

    if not posixpath.isfile(scenes_full_path):
        raise FileNotFoundError(f"The scenes file {scenes_full_path} does not exist.")

    video_mp4_path = posixpath.join(video_dir, f"{video_name}.mp4")
    video_mov_path = posixpath.join(video_dir, f"{video_name}.mov")
    if posixpath.isfile(video_mp4_path):
        video_full_path = video_mp4_path
    elif posixpath.isfile(video_mov_path):
        video_full_path = video_mov_path
    else:
        raise FileNotFoundError(f"Neither .mp4 nor .mov video file exists for {video_name}.")

    with open(scenes_full_path, 'r') as file:
        scenes = json.load(file)

    # Process the scenes
    scene_intervals = []
    for scene in scenes:
        start_frame = scene['starting_frame']
        scene_intervals.append(start_frame)

    intervals = sorted(scene_intervals)

    file_name = f'{video_dir}/{video_name}_frame%04d.jpg'
    select = '+'.join(f'eq(n,{interval})' for interval in intervals)

    try:
        ffmpeg.input(video_full_path).filter('select', select).output(file_name, vsync='0').run(capture_stdout=True, capture_stderr=True)
    except ffmpeg.Error as e:
        print('stdout:', e.stdout.decode('utf8'))
        print('stderr:', e.stderr.decode('utf8'))

videos = get_all_videos(V3C1_DIR)
for video in videos:
    extract_keyframes(video)

# %% [markdown]
# ### Check that all frames in the scene files have been exported

# %%
def process_video(video_name):
    video_dir = posixpath.join(V3C1_DIR, video_name)
    scenes_full_path = posixpath.join(video_dir, f"{video_name}_scenes.json")

    if not posixpath.isfile(scenes_full_path):
        raise FileNotFoundError(f"The scenes file {scenes_full_path} does not exist.")

    with open(scenes_full_path, 'r') as file:
        scenes = json.load(file)

    # Process the scenes
    for scene in scenes:
        keyframe = scene['frame']
        image_full_path = posixpath.join(video_dir, keyframe)

        if not posixpath.isfile(image_full_path):
            raise FileNotFoundError(f"The frame file {keyframe} does not exist.")

videos = get_all_videos(V3C1_DIR)
for video in videos:
    process_video(video)

# %% [markdown]
# # Generate descriptions with CLIP

# %%
import torch
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
import json

def generate_image_category(image_path):
    # Load and preprocess the image
    image = Image.open(image_path).convert("RGB")
    # image = image.resize((224, 224))    # Resize to a standard size
    inputs = processor(images=image, return_tensors="pt")

    # Generate description
    with torch.no_grad():
        outputs = model.generate(**inputs, max_new_tokens=100)
    
    # Decode the output description
    description = processor.decode(outputs[0], skip_special_tokens=True)
    return description

def process_video(video_name):
    video_dir = posixpath.join(V3C1_DIR, video_name)
    scenes_full_path = posixpath.join(video_dir, f"{video_name}_scenes.json")
    output_json_path = posixpath.join(video_dir, f"{video}_scenes_descriptions.json")

    if posixpath.isfile(output_json_path):
        print(f"The description file {output_json_path} already exists. Skipping prediction.")
        return

    if not posixpath.isfile(scenes_full_path):
        raise FileNotFoundError(f"The scenes file {scenes_full_path} does not exist.")

    print(f"Generating descriptions for the video {video_name}")

    with open(scenes_full_path, 'r') as file:
        scenes = json.load(file)

    # Process the scenes
    for scene in scenes:
        keyframe = scene['frame']
        # print(f"   Processing keyframe {keyframe}")
        image_full_path = posixpath.join(video_dir, keyframe)
        description = generate_image_category(image_full_path)
        scene['description'] = description

    with open(output_json_path, 'w') as json_file:
        json.dump(scenes, json_file, indent=4)

# Load the BLIP model and processor
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

videos = get_all_videos(V3C1_DIR)
for video in videos:
    process_video(video)
# Out:
# The description file A:/IVADL/V3C1-100/00100/00100_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00101/00101_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00102/00102_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00103/00103_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00104/00104_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00105/00105_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00106/00106_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00107/00107_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00108/00108_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00109/00109_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00110/00110_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00111/00111_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00112/00112_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00113/00113_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00114/00114_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00115/00115_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00116/00116_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00117/00117_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00118/00118_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00119/00119_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00120/00120_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00121/00121_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00122/00122_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00123/00123_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00124/00124_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00125/00125_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00126/00126_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00127/00127_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00128/00128_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00129/00129_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00130/00130_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00131/00131_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00132/00132_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00133/00133_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00134/00134_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00135/00135_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00136/00136_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00137/00137_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00138/00138_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00139/00139_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00140/00140_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00141/00141_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00142/00142_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00143/00143_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00144/00144_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00145/00145_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00146/00146_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00147/00147_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00148/00148_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00149/00149_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00150/00150_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00151/00151_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00152/00152_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00153/00153_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00154/00154_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00155/00155_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00156/00156_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00157/00157_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00158/00158_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00159/00159_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00160/00160_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00161/00161_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00162/00162_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00163/00163_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00164/00164_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00165/00165_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00166/00166_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00167/00167_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00168/00168_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00169/00169_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00170/00170_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00171/00171_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00172/00172_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00173/00173_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00174/00174_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00175/00175_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00176/00176_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00177/00177_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00178/00178_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00179/00179_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00180/00180_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00181/00181_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00182/00182_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00183/00183_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00184/00184_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00185/00185_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00186/00186_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00187/00187_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00188/00188_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00189/00189_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00190/00190_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00191/00191_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00192/00192_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00193/00193_scenes_descriptions.json already exists. Skipping prediction.
# The description file A:/IVADL/V3C1-100/00194/00194_scenes_descriptions.json already exists. Skipping prediction.
# Generating descriptions for the video 00195
# Generating descriptions for the video 00196
# Generating descriptions for the video 00197
# Generating descriptions for the video 00198
# Generating descriptions for the video 00199

# %% [markdown]
# # Generate categories with YOLO

# %%
from ultralytics import YOLO
from PIL import Image
import json

def generate_image_category(image_path):
    # Load and resize the image
    with Image.open(image_path) as img:
        resized_img = img.resize((224, 224))  # Resize the image to 224x224

    # Use the model to make predictions
    results = model.predict(resized_img)

    # Extract the predictions
    output = results[0].verbose()
    print(output)
    quit

    # Get the first prediction and split the name and value
    top_prediction = output.split(", ")[0]
    name, value = top_prediction.split(" ")

    # Store the category only if value >= 0.10
    category = name if float(value) >= 0.10 else ""
    return category

def process_video(video_name):
    video_dir = posixpath.join(V3C1_DIR, video_name)
    descriptions_json_path = posixpath.join(video_dir, f"{video}_scenes_descriptions.json")
    categories_full_path = posixpath.join(video_dir, f"{video_name}_scenes_descriptions_categories.json")

    if posixpath.isfile(categories_full_path):
        print(f"The category file {categories_full_path} already exists. Skipping prediction.")
        return

    if not posixpath.isfile(descriptions_json_path):
        raise FileNotFoundError(f"The scenes file {descriptions_json_path} does not exist.")

    with open(descriptions_json_path, 'r') as file:
        scenes = json.load(file)

    # Process the scenes
    for scene in scenes:
        keyframe = scene['frame']
        image_full_path = posixpath.join(video_dir, keyframe)
        category = generate_image_category(image_full_path)
        scene['category'] = category

    with open(categories_full_path, 'w') as json_file:
        json.dump(scenes, json_file, indent=4)

# Load a pretrained model
model = YOLO("yolov8m-cls.pt")

videos = get_all_videos(V3C1_DIR)
for video in videos:
    process_video(video)
# Out:
# 0: 224x224 matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02,
#
# 0: 224x224 toaster 0.32, organ 0.19, theater_curtain 0.07, tripod 0.04, upright 0.03, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# toaster 0.32, organ 0.19, theater_curtain 0.07, tripod 0.04, upright 0.03,
#
# 0: 224x224 organ 0.37, theater_curtain 0.19, chime 0.08, toaster 0.06, upright 0.03, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# organ 0.37, theater_curtain 0.19, chime 0.08, toaster 0.06, upright 0.03,
#
# 0: 224x224 chain 0.10, spotlight 0.08, lampshade 0.07, digital_clock 0.06, strainer 0.05, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# chain 0.10, spotlight 0.08, lampshade 0.07, digital_clock 0.06, strainer 0.05,
#
# 0: 224x224 organ 0.18, toaster 0.15, guillotine 0.07, dome 0.06, lampshade 0.04, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# organ 0.18, toaster 0.15, guillotine 0.07, dome 0.06, lampshade 0.04,
#
# 0: 224x224 spotlight 0.29, lampshade 0.12, traffic_light 0.07, microphone 0.06, abacus 0.04, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# spotlight 0.29, lampshade 0.12, traffic_light 0.07, microphone 0.06, abacus 0.04,
#
# 0: 224x224 switch 0.18, tape_player 0.11, radio 0.09, photocopier 0.09, cassette_player 0.06, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# switch 0.18, tape_player 0.11, radio 0.09, photocopier 0.09, cassette_player 0.06,
#
# 0: 224x224 shoji 0.26, window_screen 0.26, window_shade 0.25, sliding_door 0.04, hook 0.02, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# shoji 0.26, window_screen 0.26, window_shade 0.25, sliding_door 0.04, hook 0.02,
#
# 0: 224x224 medicine_chest 0.60, switch 0.08, wall_clock 0.04, television 0.04, prison 0.04, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# medicine_chest 0.60, switch 0.08, wall_clock 0.04, television 0.04, prison 0.04,
#
# 0: 224x224 switch 0.31, wardrobe 0.21, refrigerator 0.18, sliding_door 0.12, safe 0.02, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# switch 0.31, wardrobe 0.21, refrigerator 0.18, sliding_door 0.12, safe 0.02,
#
# 0: 224x224 lampshade 0.13, shoji 0.09, window_shade 0.06, shower_curtain 0.04, pedestal 0.04, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lampshade 0.13, shoji 0.09, window_shade 0.06, shower_curtain 0.04, pedestal 0.04,
#
# 0: 224x224 window_screen 0.50, shoji 0.18, window_shade 0.17, sliding_door 0.03, screen 0.01, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# window_screen 0.50, shoji 0.18, window_shade 0.17, sliding_door 0.03, screen 0.01,
#
# 0: 224x224 academic_gown 0.08, bow_tie 0.08, harmonica 0.06, prison 0.06, cowboy_hat 0.05, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# academic_gown 0.08, bow_tie 0.08, harmonica 0.06, prison 0.06, cowboy_hat 0.05,
#
# 0: 224x224 dumbbell 0.68, plunger 0.06, toilet_tissue 0.05, microphone 0.05, barbell 0.03, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# dumbbell 0.68, plunger 0.06, toilet_tissue 0.05, microphone 0.05, barbell 0.03,
#
# 0: 224x224 suit 0.10, neck_brace 0.09, bow_tie 0.08, hand_blower 0.05, cellular_telephone 0.05, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# suit 0.10, neck_brace 0.09, bow_tie 0.08, hand_blower 0.05, cellular_telephone 0.05,
#
# 0: 224x224 suit 0.26, abaya 0.19, academic_gown 0.05, bow_tie 0.03, Windsor_tie 0.03, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# suit 0.26, abaya 0.19, academic_gown 0.05, bow_tie 0.03, Windsor_tie 0.03,
#
# 0: 224x224 bow_tie 0.19, bubble 0.07, Band_Aid 0.06, ping-pong_ball 0.05, lipstick 0.05, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# bow_tie 0.19, bubble 0.07, Band_Aid 0.06, ping-pong_ball 0.05, lipstick 0.05,
#
# 0: 224x224 suit 0.24, groom 0.22, Windsor_tie 0.18, bow_tie 0.08, kimono 0.05, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# suit 0.24, groom 0.22, Windsor_tie 0.18, bow_tie 0.08, kimono 0.05,
#
# 0: 224x224 prison 0.72, shoji 0.11, window_shade 0.08, window_screen 0.02, cleaver 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# prison 0.72, shoji 0.11, window_shade 0.08, window_screen 0.02, cleaver 0.01,
#
# 0: 224x224 window_shade 0.36, window_screen 0.17, prison 0.13, sliding_door 0.07, radiator 0.03, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# window_shade 0.36, window_screen 0.17, prison 0.13, sliding_door 0.07, radiator 0.03,
#
# 0: 224x224 shoji 0.63, desktop_computer 0.06, sliding_door 0.05, safe 0.02, digital_clock 0.02, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# shoji 0.63, desktop_computer 0.06, sliding_door 0.05, safe 0.02, digital_clock 0.02,
#
# 0: 224x224 theater_curtain 0.38, prison 0.06, abaya 0.04, radiator 0.04, wardrobe 0.03, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# theater_curtain 0.38, prison 0.06, abaya 0.04, radiator 0.04, wardrobe 0.03,
#
# 0: 224x224 shoji 0.48, sliding_door 0.32, refrigerator 0.02, cash_machine 0.02, window_shade 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# shoji 0.48, sliding_door 0.32, refrigerator 0.02, cash_machine 0.02, window_shade 0.01,
#
# 0: 224x224 bulletproof_vest 0.19, suit 0.10, shower_cap 0.07, sweatshirt 0.06, bow_tie 0.06, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# bulletproof_vest 0.19, suit 0.10, shower_cap 0.07, sweatshirt 0.06, bow_tie 0.06,
#
# 0: 224x224 prison 0.16, upright 0.15, window_shade 0.11, toaster 0.08, sliding_door 0.05, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# prison 0.16, upright 0.15, window_shade 0.11, toaster 0.08, sliding_door 0.05,
#
# 0: 224x224 theater_curtain 0.18, suit 0.08, Windsor_tie 0.05, bow_tie 0.04, sliding_door 0.04, 15.0ms
# Speed: 1.9ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# theater_curtain 0.18, suit 0.08, Windsor_tie 0.05, bow_tie 0.04, sliding_door 0.04,
#
# 0: 224x224 theater_curtain 0.19, window_shade 0.07, suit 0.06, bow_tie 0.04, grand_piano 0.04, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# theater_curtain 0.19, window_shade 0.07, suit 0.06, bow_tie 0.04, grand_piano 0.04,
#
# 0: 224x224 mask 0.20, abaya 0.10, cloak 0.06, trench_coat 0.06, suit 0.05, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mask 0.20, abaya 0.10, cloak 0.06, trench_coat 0.06, suit 0.05,
#
# 0: 224x224 window_shade 0.63, prison 0.12, window_screen 0.07, shoji 0.02, space_heater 0.01, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# window_shade 0.63, prison 0.12, window_screen 0.07, shoji 0.02, space_heater 0.01,
#
# 0: 224x224 suit 0.49, bow_tie 0.23, Windsor_tie 0.14, lab_coat 0.01, theater_curtain 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# suit 0.49, bow_tie 0.23, Windsor_tie 0.14, lab_coat 0.01, theater_curtain 0.01,
#
# 0: 224x224 mortarboard 0.18, academic_gown 0.09, suit 0.06, trench_coat 0.04, bow_tie 0.04, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mortarboard 0.18, academic_gown 0.09, suit 0.06, trench_coat 0.04, bow_tie 0.04,
#
# 0: 224x224 radiator 0.23, window_shade 0.11, suit 0.09, prison 0.07, theater_curtain 0.05, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# radiator 0.23, window_shade 0.11, suit 0.09, prison 0.07, theater_curtain 0.05,
#
# 0: 224x224 prison 0.18, chime 0.15, radiator 0.13, matchstick 0.11, nail 0.03, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# prison 0.18, chime 0.15, radiator 0.13, matchstick 0.11, nail 0.03,
#
# 0: 224x224 suit 0.58, trench_coat 0.21, academic_gown 0.02, groom 0.02, abaya 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# suit 0.58, trench_coat 0.21, academic_gown 0.02, groom 0.02, abaya 0.02,
#
# 0: 224x224 prison 0.64, radiator 0.27, crib 0.03, window_shade 0.01, rocking_chair 0.01, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# prison 0.64, radiator 0.27, crib 0.03, window_shade 0.01, rocking_chair 0.01,
#
# 0: 224x224 sliding_door 0.24, shoji 0.12, trench_coat 0.06, cash_machine 0.06, groom 0.06, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sliding_door 0.24, shoji 0.12, trench_coat 0.06, cash_machine 0.06, groom 0.06,
#
# 0: 224x224 radiator 0.63, window_shade 0.05, shoji 0.05, prison 0.04, theater_curtain 0.04, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# radiator 0.63, window_shade 0.05, shoji 0.05, prison 0.04, theater_curtain 0.04,
#
# 0: 224x224 window_shade 0.75, suit 0.04, shoji 0.02, cash_machine 0.02, bow_tie 0.02, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# window_shade 0.75, suit 0.04, shoji 0.02, cash_machine 0.02, bow_tie 0.02,
#
# 0: 224x224 radiator 0.50, theater_curtain 0.15, prison 0.05, window_shade 0.05, space_heater 0.02, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# radiator 0.50, theater_curtain 0.15, prison 0.05, window_shade 0.05, space_heater 0.02,
#
# 0: 224x224 groom 0.25, window_shade 0.21, suit 0.09, Windsor_tie 0.06, bow_tie 0.05, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# groom 0.25, window_shade 0.21, suit 0.09, Windsor_tie 0.06, bow_tie 0.05,
#
# 0: 224x224 radiator 0.28, prison 0.26, window_shade 0.08, theater_curtain 0.04, shoji 0.03, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# radiator 0.28, prison 0.26, window_shade 0.08, theater_curtain 0.04, shoji 0.03,
#
# 0: 224x224 shoji 0.87, sliding_door 0.07, window_screen 0.03, window_shade 0.02, prison 0.00, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# shoji 0.87, sliding_door 0.07, window_screen 0.03, window_shade 0.02, prison 0.00,
#
# 0: 224x224 mosquito_net 0.19, shower_curtain 0.18, dishwasher 0.04, lampshade 0.03, wardrobe 0.03, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# mosquito_net 0.19, shower_curtain 0.18, dishwasher 0.04, lampshade 0.03, wardrobe 0.03,
#
# 0: 224x224 abaya 0.07, switch 0.06, punching_bag 0.04, prison 0.03, upright 0.03, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# abaya 0.07, switch 0.06, punching_bag 0.04, prison 0.03, upright 0.03,
#
# 0: 224x224 suit 0.34, groom 0.30, bow_tie 0.15, Windsor_tie 0.05, neck_brace 0.03, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# suit 0.34, groom 0.30, bow_tie 0.15, Windsor_tie 0.05, neck_brace 0.03,
#
# 0: 224x224 bow_tie 0.16, Band_Aid 0.09, lab_coat 0.05, shower_cap 0.03, suit 0.03, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# bow_tie 0.16, Band_Aid 0.09, lab_coat 0.05, shower_cap 0.03, suit 0.03,
#
# 0: 224x224 academic_gown 0.29, suit 0.28, mortarboard 0.16, Windsor_tie 0.04, bow_tie 0.04, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# academic_gown 0.29, suit 0.28, mortarboard 0.16, Windsor_tie 0.04, bow_tie 0.04,
#
# 0: 224x224 suit 0.14, Windsor_tie 0.13, bow_tie 0.12, lab_coat 0.04, hair_spray 0.03, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# suit 0.14, Windsor_tie 0.13, bow_tie 0.12, lab_coat 0.04, hair_spray 0.03,
#
# 0: 224x224 spotlight 0.11, water_bottle 0.08, switch 0.08, cocktail_shaker 0.06, screw 0.04, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# spotlight 0.11, water_bottle 0.08, switch 0.08, cocktail_shaker 0.06, screw 0.04,
#
# 0: 224x224 suit 0.48, barbell 0.05, bow_tie 0.04, plunger 0.04, vacuum 0.03, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# suit 0.48, barbell 0.05, bow_tie 0.04, plunger 0.04, vacuum 0.03,
#
# 0: 224x224 mask 0.42, abaya 0.23, bow_tie 0.05, neck_brace 0.05, iron 0.02, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mask 0.42, abaya 0.23, bow_tie 0.05, neck_brace 0.05, iron 0.02,
#
# 0: 224x224 bow_tie 0.22, seat_belt 0.06, suit 0.05, Band_Aid 0.03, perfume 0.03, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# bow_tie 0.22, seat_belt 0.06, suit 0.05, Band_Aid 0.03, perfume 0.03,
#
# 0: 224x224 matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02,
#
# 0: 224x224 matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02,
#
# 0: 224x224 wall_clock 0.42, analog_clock 0.36, unicycle 0.05, whistle 0.02, magnetic_compass 0.02, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# wall_clock 0.42, analog_clock 0.36, unicycle 0.05, whistle 0.02, magnetic_compass 0.02,
#
# 0: 224x224 matchstick 0.03, digital_clock 0.03, honeycomb 0.02, nematode 0.02, envelope 0.02, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# matchstick 0.03, digital_clock 0.03, honeycomb 0.02, nematode 0.02, envelope 0.02,
#
# 0: 224x224 ambulance 0.27, streetcar 0.07, cab 0.06, fire_engine 0.06, minibus 0.04, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# ambulance 0.27, streetcar 0.07, cab 0.06, fire_engine 0.06, minibus 0.04,
#
# 0: 224x224 mobile_home 0.18, stupa 0.10, thatch 0.10, yurt 0.05, mailbox 0.04, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mobile_home 0.18, stupa 0.10, thatch 0.10, yurt 0.05, mailbox 0.04,
#
# 0: 224x224 pole 0.52, flagpole 0.23, obelisk 0.12, geyser 0.02, beacon 0.02, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# pole 0.52, flagpole 0.23, obelisk 0.12, geyser 0.02, beacon 0.02,
#
# 0: 224x224 cab 0.32, tow_truck 0.09, moving_van 0.07, fire_engine 0.07, mosque 0.07, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cab 0.32, tow_truck 0.09, moving_van 0.07, fire_engine 0.07, mosque 0.07,
#
# 0: 224x224 pickup 0.91, mobile_home 0.02, recreational_vehicle 0.02, jeep 0.02, fire_engine 0.01, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# pickup 0.91, mobile_home 0.02, recreational_vehicle 0.02, jeep 0.02, fire_engine 0.01,
#
# 0: 224x224 lakeside 0.37, patio 0.33, seashore 0.09, sandbar 0.04, monastery 0.01, 5.0ms
# Speed: 1.9ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lakeside 0.37, patio 0.33, seashore 0.09, sandbar 0.04, monastery 0.01,
#
# 0: 224x224 lakeside 0.86, valley 0.04, water_buffalo 0.01, sandbar 0.01, rapeseed 0.01, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lakeside 0.86, valley 0.04, water_buffalo 0.01, sandbar 0.01, rapeseed 0.01,
#
# 0: 224x224 jean 0.14, gown 0.08, miniskirt 0.07, sweatshirt 0.05, sunglasses 0.04, 5.0ms
# Speed: 3.1ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# jean 0.14, gown 0.08, miniskirt 0.07, sweatshirt 0.05, sunglasses 0.04,
#
# 0: 224x224 lakeside 0.64, dock 0.09, breakwater 0.08, boathouse 0.05, pier 0.02, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lakeside 0.64, dock 0.09, breakwater 0.08, boathouse 0.05, pier 0.02,
#
# 0: 224x224 water_tower 1.00, beacon 0.00, torch 0.00, monastery 0.00, chime 0.00, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# water_tower 1.00, beacon 0.00, torch 0.00, monastery 0.00, chime 0.00,
#
# 0: 224x224 lakeside 0.10, container_ship 0.09, castle 0.06, cliff 0.06, gondola 0.06, 5.0ms
# Speed: 1.9ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lakeside 0.10, container_ship 0.09, castle 0.06, cliff 0.06, gondola 0.06,
#
# 0: 224x224 castle 0.30, lakeside 0.15, container_ship 0.09, dock 0.08, promontory 0.05, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# castle 0.30, lakeside 0.15, container_ship 0.09, dock 0.08, promontory 0.05,
#
# 0: 224x224 sweatshirt 0.19, maillot_(tights) 0.10, swimming_trunks 0.05, pajama 0.05, maillot_(tank_suit) 0.05, 4.9ms
# Speed: 2.1ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sweatshirt 0.19, maillot_(tights) 0.10, swimming_trunks 0.05, pajama 0.05, maillot_(tank_suit) 0.05,
#
# 0: 224x224 cardigan 0.61, sunglasses 0.08, maillot_(tights) 0.05, sunglass 0.03, stole 0.03, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cardigan 0.61, sunglasses 0.08, maillot_(tights) 0.05, sunglass 0.03, stole 0.03,
#
# 0: 224x224 cliff 0.38, cliff_dwelling 0.35, promontory 0.04, valley 0.03, monastery 0.02, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# cliff 0.38, cliff_dwelling 0.35, promontory 0.04, valley 0.03, monastery 0.02,
#
# 0: 224x224 sarong 0.43, miniskirt 0.28, overskirt 0.04, gown 0.03, maillot_(tank_suit) 0.03, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sarong 0.43, miniskirt 0.28, overskirt 0.04, gown 0.03, maillot_(tank_suit) 0.03,
#
# 0: 224x224 crutch 0.53, swab 0.23, wardrobe 0.02, tripod 0.02, sarong 0.02, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# crutch 0.53, swab 0.23, wardrobe 0.02, tripod 0.02, sarong 0.02,
#
# 0: 224x224 chain_saw 0.21, cliff_dwelling 0.16, picket_fence 0.06, rain_barrel 0.06, dam 0.06, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# chain_saw 0.21, cliff_dwelling 0.16, picket_fence 0.06, rain_barrel 0.06, dam 0.06,
#
# 0: 224x224 dam 0.22, crib 0.21, cliff 0.15, bannister 0.11, cradle 0.07, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# dam 0.22, crib 0.21, cliff 0.15, bannister 0.11, cradle 0.07,
#
# 0: 224x224 sarong 0.34, gown 0.21, shower_cap 0.12, plastic_bag 0.02, paintbrush 0.01, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sarong 0.34, gown 0.21, shower_cap 0.12, plastic_bag 0.02, paintbrush 0.01,
#
# 0: 224x224 sarong 0.38, monastery 0.07, mosque 0.06, gown 0.05, bathing_cap 0.04, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sarong 0.38, monastery 0.07, mosque 0.06, gown 0.05, bathing_cap 0.04,
#
# 0: 224x224 cliff_dwelling 0.28, tub 0.09, racket 0.07, swab 0.04, prison 0.04, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cliff_dwelling 0.28, tub 0.09, racket 0.07, swab 0.04, prison 0.04,
#
# 0: 224x224 crutch 0.26, cash_machine 0.15, prison 0.13, swab 0.05, racket 0.04, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# crutch 0.26, cash_machine 0.15, prison 0.13, swab 0.05, racket 0.04,
#
# 0: 224x224 sarong 0.31, torch 0.07, punching_bag 0.05, shield 0.03, carton 0.03, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sarong 0.31, torch 0.07, punching_bag 0.05, shield 0.03, carton 0.03,
#
# 0: 224x224 prison 0.36, patio 0.31, monastery 0.12, mosque 0.10, abaya 0.01, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# prison 0.36, patio 0.31, monastery 0.12, mosque 0.10, abaya 0.01,
#
# 0: 224x224 panpipe 0.17, jersey 0.05, sunglass 0.04, jean 0.04, sarong 0.04, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# panpipe 0.17, jersey 0.05, sunglass 0.04, jean 0.04, sarong 0.04,
#
# 0: 224x224 shower_curtain 0.53, gasmask 0.10, lab_coat 0.09, mosquito_net 0.02, wardrobe 0.02, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# shower_curtain 0.53, gasmask 0.10, lab_coat 0.09, mosquito_net 0.02, wardrobe 0.02,
#
# 0: 224x224 wardrobe 0.10, stole 0.10, sarong 0.09, shower_curtain 0.09, suit 0.05, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# wardrobe 0.10, stole 0.10, sarong 0.09, shower_curtain 0.09, suit 0.05,
#
# 0: 224x224 torch 0.22, volleyball 0.16, lab_coat 0.15, paintbrush 0.08, vestment 0.05, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# torch 0.22, volleyball 0.16, lab_coat 0.15, paintbrush 0.08, vestment 0.05,
#
# 0: 224x224 torch 0.35, volleyball 0.13, lab_coat 0.12, vestment 0.08, paintbrush 0.06, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# torch 0.35, volleyball 0.13, lab_coat 0.12, vestment 0.08, paintbrush 0.06,
#
# 0: 224x224 volleyball 0.40, swimming_trunks 0.16, bikini 0.10, maillot_(tights) 0.03, soccer_ball 0.02, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# volleyball 0.40, swimming_trunks 0.16, bikini 0.10, maillot_(tights) 0.03, soccer_ball 0.02,
#
# 0: 224x224 volleyball 0.55, bikini 0.06, swimming_trunks 0.05, racket 0.03, soccer_ball 0.03, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# volleyball 0.55, bikini 0.06, swimming_trunks 0.05, racket 0.03, soccer_ball 0.03,
#
# 0: 224x224 megalith 0.57, missile 0.16, obelisk 0.11, totem_pole 0.09, sandbar 0.02, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# megalith 0.57, missile 0.16, obelisk 0.11, totem_pole 0.09, sandbar 0.02,
#
# 0: 224x224 sunglass 0.40, sunglasses 0.12, sarong 0.08, suit 0.02, torch 0.02, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sunglass 0.40, sunglasses 0.12, sarong 0.08, suit 0.02, torch 0.02,
#
# 0: 224x224 sunglass 0.47, sunglasses 0.16, sarong 0.04, cellular_telephone 0.04, whistle 0.02, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sunglass 0.47, sunglasses 0.16, sarong 0.04, cellular_telephone 0.04, whistle 0.02,
#
# 0: 224x224 obelisk 0.43, missile 0.29, monastery 0.04, abaya 0.04, megalith 0.04, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# obelisk 0.43, missile 0.29, monastery 0.04, abaya 0.04, megalith 0.04,
#
# 0: 224x224 obelisk 0.75, totem_pole 0.14, megalith 0.03, bell_cote 0.02, pedestal 0.02, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# obelisk 0.75, totem_pole 0.14, megalith 0.03, bell_cote 0.02, pedestal 0.02,
#
# 0: 224x224 obelisk 0.38, pedestal 0.31, cannon 0.15, vault 0.04, monastery 0.02, 4.9ms
# Speed: 2.1ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# obelisk 0.38, pedestal 0.31, cannon 0.15, vault 0.04, monastery 0.02,
#
# 0: 224x224 vault 0.24, lumbermill 0.10, obelisk 0.08, mosque 0.07, pedestal 0.06, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# vault 0.24, lumbermill 0.10, obelisk 0.08, mosque 0.07, pedestal 0.06,
#
# 0: 224x224 crutch 0.42, pedestal 0.07, cliff_dwelling 0.07, cash_machine 0.06, vault 0.04, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# crutch 0.42, pedestal 0.07, cliff_dwelling 0.07, cash_machine 0.06, vault 0.04,
#
# 0: 224x224 obelisk 0.49, pedestal 0.30, triumphal_arch 0.06, vault 0.05, monastery 0.02, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# obelisk 0.49, pedestal 0.30, triumphal_arch 0.06, vault 0.05, monastery 0.02,
#
# 0: 224x224 sarong 0.72, ashcan 0.11, chain_saw 0.01, barrel 0.01, water_jug 0.01, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sarong 0.72, ashcan 0.11, chain_saw 0.01, barrel 0.01, water_jug 0.01,
#
# 0: 224x224 cliff_dwelling 0.15, lumbermill 0.10, vault 0.08, carton 0.08, prison 0.07, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cliff_dwelling 0.15, lumbermill 0.10, vault 0.08, carton 0.08, prison 0.07,
#
# 0: 224x224 sarong 0.63, plunger 0.06, sunglass 0.05, obelisk 0.05, crutch 0.05, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sarong 0.63, plunger 0.06, sunglass 0.05, obelisk 0.05, crutch 0.05,
#
# 0: 224x224 pedestal 0.35, obelisk 0.19, lumbermill 0.16, vault 0.09, totem_pole 0.05, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# pedestal 0.35, obelisk 0.19, lumbermill 0.16, vault 0.09, totem_pole 0.05,
#
# 0: 224x224 punching_bag 0.21, pole 0.06, projectile 0.05, obelisk 0.04, sunglass 0.04, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# punching_bag 0.21, pole 0.06, projectile 0.05, obelisk 0.04, sunglass 0.04,
#
# 0: 224x224 obelisk 0.30, triumphal_arch 0.20, pedestal 0.19, vault 0.17, monastery 0.06, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# obelisk 0.30, triumphal_arch 0.20, pedestal 0.19, vault 0.17, monastery 0.06,
#
# 0: 224x224 obelisk 1.00, pedestal 0.00, mosque 0.00, projectile 0.00, missile 0.00, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# obelisk 1.00, pedestal 0.00, mosque 0.00, projectile 0.00, missile 0.00,
#
# 0: 224x224 swing 0.50, mosque 0.07, miniskirt 0.05, maillot_(tights) 0.04, bikini 0.03, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# swing 0.50, mosque 0.07, miniskirt 0.05, maillot_(tights) 0.04, bikini 0.03,
#
# 0: 224x224 swing 0.65, mosque 0.06, bikini 0.03, miniskirt 0.02, maillot_(tights) 0.02, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# swing 0.65, mosque 0.06, bikini 0.03, miniskirt 0.02, maillot_(tights) 0.02,
#
# 0: 224x224 lab_coat 0.91, torch 0.02, military_uniform 0.02, stage 0.01, suit 0.00, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lab_coat 0.91, torch 0.02, military_uniform 0.02, stage 0.01, suit 0.00,
#
# 0: 224x224 stage 0.12, lab_coat 0.10, ocarina 0.09, racket 0.07, oboe 0.05, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# stage 0.12, lab_coat 0.10, ocarina 0.09, racket 0.07, oboe 0.05,
#
# 0: 224x224 obelisk 0.49, pole 0.10, pedestal 0.09, bikini 0.04, volleyball 0.04, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# obelisk 0.49, pole 0.10, pedestal 0.09, bikini 0.04, volleyball 0.04,
#
# 0: 224x224 gown 0.16, sunglass 0.09, stole 0.07, velvet 0.06, sarong 0.04, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# gown 0.16, sunglass 0.09, stole 0.07, velvet 0.06, sarong 0.04,
#
# 0: 224x224 shower_curtain 0.21, racket 0.15, vestment 0.09, paintbrush 0.06, shower_cap 0.05, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# shower_curtain 0.21, racket 0.15, vestment 0.09, paintbrush 0.06, shower_cap 0.05,
#
# 0: 224x224 crutch 0.19, sunglass 0.16, vestment 0.08, sunglasses 0.08, jersey 0.04, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# crutch 0.19, sunglass 0.16, vestment 0.08, sunglasses 0.08, jersey 0.04,
#
# 0: 224x224 sarong 0.10, stethoscope 0.08, basketball 0.06, brassiere 0.04, miniskirt 0.04, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sarong 0.10, stethoscope 0.08, basketball 0.06, brassiere 0.04, miniskirt 0.04,
#
# 0: 224x224 sarong 0.11, stethoscope 0.08, basketball 0.06, plunger 0.04, iron 0.03, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sarong 0.11, stethoscope 0.08, basketball 0.06, plunger 0.04, iron 0.03,
#
# 0: 224x224 crutch 0.28, unicycle 0.15, miniskirt 0.06, sandbar 0.05, pajama 0.03, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# crutch 0.28, unicycle 0.15, miniskirt 0.06, sandbar 0.05, pajama 0.03,
#
# 0: 224x224 picket_fence 0.16, gondola 0.12, bell_cote 0.08, guillotine 0.07, crutch 0.06, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# picket_fence 0.16, gondola 0.12, bell_cote 0.08, guillotine 0.07, crutch 0.06,
#
# 0: 224x224 pajama 0.20, abaya 0.13, sarong 0.12, crutch 0.11, neck_brace 0.06, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# pajama 0.20, abaya 0.13, sarong 0.12, crutch 0.11, neck_brace 0.06,
#
# 0: 224x224 sarong 0.28, crutch 0.18, jersey 0.07, sunglasses 0.03, bicycle-built-for-two 0.02, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# sarong 0.28, crutch 0.18, jersey 0.07, sunglasses 0.03, bicycle-built-for-two 0.02,
#
# 0: 224x224 mosque 0.14, picket_fence 0.13, triumphal_arch 0.06, obelisk 0.05, palace 0.05, 5.0ms
# Speed: 3.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mosque 0.14, picket_fence 0.13, triumphal_arch 0.06, obelisk 0.05, palace 0.05,
#
# 0: 224x224 mosque 0.45, obelisk 0.11, triumphal_arch 0.07, vault 0.06, monastery 0.05, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mosque 0.45, obelisk 0.11, triumphal_arch 0.07, vault 0.06, monastery 0.05,
#
# 0: 224x224 Arabian_camel 0.54, fireboat 0.12, dam 0.08, breakwater 0.04, cannon 0.04, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Arabian_camel 0.54, fireboat 0.12, dam 0.08, breakwater 0.04, cannon 0.04,
#
# 0: 224x224 cannon 0.57, dam 0.15, fireboat 0.05, cliff 0.04, breakwater 0.03, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cannon 0.57, dam 0.15, fireboat 0.05, cliff 0.04, breakwater 0.03,
#
# 0: 224x224 lab_coat 0.81, shower_cap 0.13, abaya 0.02, vestment 0.01, racket 0.01, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lab_coat 0.81, shower_cap 0.13, abaya 0.02, vestment 0.01, racket 0.01,
#
# 0: 224x224 lab_coat 0.62, shower_cap 0.15, vestment 0.05, torch 0.04, abaya 0.04, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lab_coat 0.62, shower_cap 0.15, vestment 0.05, torch 0.04, abaya 0.04,
#
# 0: 224x224 fountain 0.51, cliff 0.17, megalith 0.14, vault 0.07, Arabian_camel 0.01, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# fountain 0.51, cliff 0.17, megalith 0.14, vault 0.07, Arabian_camel 0.01,
#
# 0: 224x224 swimming_trunks 0.18, Arabian_camel 0.13, bloodhound 0.11, cowboy_hat 0.05, vault 0.04, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# swimming_trunks 0.18, Arabian_camel 0.13, bloodhound 0.11, cowboy_hat 0.05, vault 0.04,
#
# 0: 224x224 obelisk 0.35, castle 0.31, pedestal 0.06, megalith 0.05, fireboat 0.04, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# obelisk 0.35, castle 0.31, pedestal 0.06, megalith 0.05, fireboat 0.04,
#
# 0: 224x224 overskirt 0.20, abaya 0.16, chain_mail 0.11, miniskirt 0.08, hoopskirt 0.07, 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# overskirt 0.20, abaya 0.16, chain_mail 0.11, miniskirt 0.08, hoopskirt 0.07,
#
# 0: 224x224 sunglass 0.20, crutch 0.19, gondola 0.09, bathing_cap 0.08, abaya 0.07, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sunglass 0.20, crutch 0.19, gondola 0.09, bathing_cap 0.08, abaya 0.07,
#
# 0: 224x224 gown 0.26, shower_curtain 0.17, abaya 0.10, sarong 0.05, punching_bag 0.05, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# gown 0.26, shower_curtain 0.17, abaya 0.10, sarong 0.05, punching_bag 0.05,
#
# 0: 224x224 matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02,
#
# 0: 224x224 spiny_lobster 1.00, crayfish 0.00, American_lobster 0.00, grasshopper 0.00, lionfish 0.00, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# spiny_lobster 1.00, crayfish 0.00, American_lobster 0.00, grasshopper 0.00, lionfish 0.00,
#
# 0: 224x224 spiny_lobster 0.97, crayfish 0.03, American_lobster 0.00, sea_cucumber 0.00, lionfish 0.00, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# spiny_lobster 0.97, crayfish 0.03, American_lobster 0.00, sea_cucumber 0.00, lionfish 0.00,
#
# 0: 224x224 catamaran 0.24, speedboat 0.17, submarine 0.15, lifeboat 0.10, trimaran 0.09, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# catamaran 0.24, speedboat 0.17, submarine 0.15, lifeboat 0.10, trimaran 0.09,
#
# 0: 224x224 mountain_tent 0.24, folding_chair 0.15, sunglasses 0.10, bullet_train 0.06, streetcar 0.04, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mountain_tent 0.24, folding_chair 0.15, sunglasses 0.10, bullet_train 0.06, streetcar 0.04,
#
# 0: 224x224 sturgeon 0.28, mountain_tent 0.26, abaya 0.24, streetcar 0.04, television 0.01, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sturgeon 0.28, mountain_tent 0.26, abaya 0.24, streetcar 0.04, television 0.01,
#
# 0: 224x224 matchstick 0.43, scoreboard 0.15, street_sign 0.09, balance_beam 0.08, rule 0.04, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# matchstick 0.43, scoreboard 0.15, street_sign 0.09, balance_beam 0.08, rule 0.04,
#
# 0: 224x224 scoreboard 0.38, street_sign 0.11, space_shuttle 0.06, television 0.06, stage 0.05, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# scoreboard 0.38, street_sign 0.11, space_shuttle 0.06, television 0.06, stage 0.05,
#
# 0: 224x224 screen 0.34, scoreboard 0.16, television 0.12, monitor 0.06, oscilloscope 0.06, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# screen 0.34, scoreboard 0.16, television 0.12, monitor 0.06, oscilloscope 0.06,
#
# 0: 224x224 dugong 0.21, bubble 0.12, sea_lion 0.07, loggerhead 0.04, jellyfish 0.03, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# dugong 0.21, bubble 0.12, sea_lion 0.07, loggerhead 0.04, jellyfish 0.03,
#
# 0: 224x224 scuba_diver 0.85, reel 0.04, snorkel 0.02, gar 0.01, conch 0.01, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# scuba_diver 0.85, reel 0.04, snorkel 0.02, gar 0.01, conch 0.01,
#
# 0: 224x224 snorkel 0.91, swimming_trunks 0.04, stingray 0.01, electric_ray 0.01, loggerhead 0.01, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# snorkel 0.91, swimming_trunks 0.04, stingray 0.01, electric_ray 0.01, loggerhead 0.01,
#
# 0: 224x224 street_sign 0.49, monitor 0.08, screen 0.06, modem 0.04, television 0.03, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# street_sign 0.49, monitor 0.08, screen 0.06, modem 0.04, television 0.03,
#
# 0: 224x224 coral_reef 0.36, street_sign 0.22, lionfish 0.08, hen-of-the-woods 0.07, sea_anemone 0.05, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# coral_reef 0.36, street_sign 0.22, lionfish 0.08, hen-of-the-woods 0.07, sea_anemone 0.05,
#
# 0: 224x224 scuba_diver 0.86, parachute 0.06, oxygen_mask 0.01, football_helmet 0.00, warplane 0.00, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# scuba_diver 0.86, parachute 0.06, oxygen_mask 0.01, football_helmet 0.00, warplane 0.00,
#
# 0: 224x224 coral_reef 0.87, brain_coral 0.03, gyromitra 0.01, Airedale 0.01, sea_cucumber 0.01, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# coral_reef 0.87, brain_coral 0.03, gyromitra 0.01, Airedale 0.01, sea_cucumber 0.01,
#
# 0: 224x224 coral_reef 0.58, rock_beauty 0.21, electric_ray 0.06, mousetrap 0.02, dung_beetle 0.02, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# coral_reef 0.58, rock_beauty 0.21, electric_ray 0.06, mousetrap 0.02, dung_beetle 0.02,
#
# 0: 224x224 sea_cucumber 0.50, coral_reef 0.23, honeycomb 0.07, bakery 0.03, ant 0.01, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sea_cucumber 0.50, coral_reef 0.23, honeycomb 0.07, bakery 0.03, ant 0.01,
#
# 0: 224x224 sea_cucumber 0.62, rotisserie 0.14, isopod 0.06, hermit_crab 0.01, sea_slug 0.01, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sea_cucumber 0.62, rotisserie 0.14, isopod 0.06, hermit_crab 0.01, sea_slug 0.01,
#
# 0: 224x224 spiny_lobster 0.21, sea_urchin 0.07, isopod 0.06, modem 0.05, lighter 0.05, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# spiny_lobster 0.21, sea_urchin 0.07, isopod 0.06, modem 0.05, lighter 0.05,
#
# 0: 224x224 coral_reef 0.21, sea_urchin 0.15, sea_anemone 0.11, isopod 0.08, monitor 0.07, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# coral_reef 0.21, sea_urchin 0.15, sea_anemone 0.11, isopod 0.08, monitor 0.07,
#
# 0: 224x224 coral_fungus 0.41, hen-of-the-woods 0.22, coral_reef 0.08, gyromitra 0.04, whiptail 0.03, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# coral_fungus 0.41, hen-of-the-woods 0.22, coral_reef 0.08, gyromitra 0.04, whiptail 0.03,
#
# 0: 224x224 coral_reef 0.60, street_sign 0.09, rule 0.03, brain_coral 0.03, lionfish 0.02, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# coral_reef 0.60, street_sign 0.09, rule 0.03, brain_coral 0.03, lionfish 0.02,
#
# 0: 224x224 scuba_diver 0.97, parachute 0.00, comic_book 0.00, football_helmet 0.00, space_shuttle 0.00, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# scuba_diver 0.97, parachute 0.00, comic_book 0.00, football_helmet 0.00, space_shuttle 0.00,
#
# 0: 224x224 coral_reef 0.39, scuba_diver 0.35, snorkel 0.06, sea_lion 0.04, killer_whale 0.03, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# coral_reef 0.39, scuba_diver 0.35, snorkel 0.06, sea_lion 0.04, killer_whale 0.03,
#
# 0: 224x224 cliff 0.19, valley 0.11, coral_reef 0.10, hen-of-the-woods 0.08, brain_coral 0.07, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cliff 0.19, valley 0.11, coral_reef 0.10, hen-of-the-woods 0.08, brain_coral 0.07,
#
# 0: 224x224 coral_reef 0.70, scuba_diver 0.24, snorkel 0.03, parachute 0.02, cliff 0.00, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# coral_reef 0.70, scuba_diver 0.24, snorkel 0.03, parachute 0.02, cliff 0.00,
#
# 0: 224x224 loggerhead 0.18, geyser 0.14, coral_reef 0.08, promontory 0.07, sea_cucumber 0.05, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# loggerhead 0.18, geyser 0.14, coral_reef 0.08, promontory 0.07, sea_cucumber 0.05,
#
# 0: 224x224 sea_slug 0.09, candle 0.06, carousel 0.06, ashcan 0.05, bubble 0.05, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sea_slug 0.09, candle 0.06, carousel 0.06, ashcan 0.05, bubble 0.05,
#
# 0: 224x224 catamaran 0.22, trimaran 0.19, reel 0.18, schipperke 0.05, gar 0.04, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# catamaran 0.22, trimaran 0.19, reel 0.18, schipperke 0.05, gar 0.04,
#
# 0: 224x224 catamaran 0.63, amphibian 0.26, speedboat 0.05, snorkel 0.02, trimaran 0.02, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# catamaran 0.63, amphibian 0.26, speedboat 0.05, snorkel 0.02, trimaran 0.02,
#
# 0: 224x224 mountain_tent 0.37, bulletproof_vest 0.14, sturgeon 0.09, seat_belt 0.08, Model_T 0.07, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mountain_tent 0.37, bulletproof_vest 0.14, sturgeon 0.09, seat_belt 0.08, Model_T 0.07,
#
# 0: 224x224 lakeside 0.54, pirate 0.14, fountain 0.06, dock 0.06, boathouse 0.04, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lakeside 0.54, pirate 0.14, fountain 0.06, dock 0.06, boathouse 0.04,
#
# 0: 224x224 sturgeon 0.43, schooner 0.11, speedboat 0.09, trimaran 0.07, coho 0.06, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sturgeon 0.43, schooner 0.11, speedboat 0.09, trimaran 0.07, coho 0.06,
#
# 0: 224x224 mountain_tent 0.90, abaya 0.02, minibus 0.02, trimaran 0.01, speedboat 0.01, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mountain_tent 0.90, abaya 0.02, minibus 0.02, trimaran 0.01, speedboat 0.01,
#
# 0: 224x224 matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02,
#
# 0: 224x224 volcano 0.27, lakeside 0.08, space_shuttle 0.07, seashore 0.05, drilling_platform 0.04, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# volcano 0.27, lakeside 0.08, space_shuttle 0.07, seashore 0.05, drilling_platform 0.04,
#
# 0: 224x224 radio 0.20, digital_clock 0.16, space_shuttle 0.07, beaker 0.06, remote_control 0.05, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# radio 0.20, digital_clock 0.16, space_shuttle 0.07, beaker 0.06, remote_control 0.05,
#
# 0: 224x224 menu 0.28, scoreboard 0.10, radio 0.08, digital_clock 0.08, space_shuttle 0.03, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# menu 0.28, scoreboard 0.10, radio 0.08, digital_clock 0.08, space_shuttle 0.03,
#
# 0: 224x224 radio 0.30, stage 0.15, catamaran 0.14, trailer_truck 0.12, trimaran 0.04, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
# radio 0.30, stage 0.15, catamaran 0.14, trailer_truck 0.12, trimaran 0.04,
#
# 0: 224x224 suspension_bridge 0.12, spotlight 0.08, theater_curtain 0.08, grand_piano 0.07, fountain 0.07, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# suspension_bridge 0.12, spotlight 0.08, theater_curtain 0.08, grand_piano 0.07, fountain 0.07,
#
# 0: 224x224 matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02, 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# matchstick 0.02, envelope 0.02, nematode 0.02, hook 0.02, velvet 0.02,
#
# 0: 224x224 volcano 0.48, geyser 0.32, coral_reef 0.01, nematode 0.01, wood_rabbit 0.01, 7.4ms
# Speed: 1.6ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# volcano 0.48, geyser 0.32, coral_reef 0.01, nematode 0.01, wood_rabbit 0.01,
#
# 0: 224x224 grey_fox 0.07, bannister 0.04, ptarmigan 0.04, alp 0.04, lion 0.04, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# grey_fox 0.07, bannister 0.04, ptarmigan 0.04, alp 0.04, lion 0.04,
#
# 0: 224x224 dam 0.54, bannister 0.12, alp 0.10, valley 0.04, birdhouse 0.01, 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# dam 0.54, bannister 0.12, alp 0.10, valley 0.04, birdhouse 0.01,
#
# 0: 224x224 pole 0.60, nail 0.09, birdhouse 0.09, flagpole 0.06, hook 0.02, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# pole 0.60, nail 0.09, birdhouse 0.09, flagpole 0.06, hook 0.02,
#
# 0: 224x224 cello 0.26, violin 0.12, grand_piano 0.11, oboe 0.11, accordion 0.06, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cello 0.26, violin 0.12, grand_piano 0.11, oboe 0.11, accordion 0.06,
#
# 0: 224x224 cash_machine 0.32, pay-phone 0.24, parking_meter 0.07, gas_pump 0.06, minivan 0.05, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cash_machine 0.32, pay-phone 0.24, parking_meter 0.07, gas_pump 0.06, minivan 0.05,
#
# ...
# Speed: 3.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# traffic_light 0.15, freight_car 0.07, electric_locomotive 0.06, passenger_car 0.04, moving_van 0.04,
#
# 0: 224x224 electric_locomotive 0.90, passenger_car 0.07, streetcar 0.03, trolleybus 0.00, freight_car 0.00, 16.8ms
# Speed: 3.0ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# electric_locomotive 0.90, passenger_car 0.07, streetcar 0.03, trolleybus 0.00, freight_car 0.00,
#
# 0: 224x224 alp 0.37, valley 0.17, lakeside 0.14, sandbar 0.07, promontory 0.05, 17.0ms
# Speed: 3.4ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# alp 0.37, valley 0.17, lakeside 0.14, sandbar 0.07, promontory 0.05,
#
# 0: 224x224 valley 0.18, hay 0.17, lakeside 0.17, rapeseed 0.14, alp 0.04, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# valley 0.18, hay 0.17, lakeside 0.17, rapeseed 0.14, alp 0.04,
#
# 0: 224x224 alp 0.77, valley 0.07, lakeside 0.02, promontory 0.02, cliff 0.01, 17.5ms
# Speed: 2.9ms preprocess, 17.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# alp 0.77, valley 0.07, lakeside 0.02, promontory 0.02, cliff 0.01,
#
# 0: 224x224 rapeseed 0.53, worm_fence 0.07, harvester 0.06, pole 0.04, shovel 0.04, 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# rapeseed 0.53, worm_fence 0.07, harvester 0.06, pole 0.04, shovel 0.04,
#
# 0: 224x224 hook 0.12, birdhouse 0.12, frilled_lizard 0.11, knot 0.09, gyromitra 0.09, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# hook 0.12, birdhouse 0.12, frilled_lizard 0.11, knot 0.09, gyromitra 0.09,
#
# 0: 224x224 castle 0.48, monastery 0.10, maze 0.06, thatch 0.06, bell_cote 0.03, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# castle 0.48, monastery 0.10, maze 0.06, thatch 0.06, bell_cote 0.03,
#
# 0: 224x224 boathouse 0.53, mobile_home 0.10, greenhouse 0.09, birdhouse 0.04, barn 0.04, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# boathouse 0.53, mobile_home 0.10, greenhouse 0.09, birdhouse 0.04, barn 0.04,
#
# 0: 224x224 pier 0.66, lakeside 0.10, bannister 0.05, steel_arch_bridge 0.04, patio 0.03, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# pier 0.66, lakeside 0.10, bannister 0.05, steel_arch_bridge 0.04, patio 0.03,
#
# 0: 224x224 skunk 0.07, badger 0.06, armadillo 0.04, vulture 0.04, black_stork 0.04, 16.9ms
# Speed: 3.0ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# skunk 0.07, badger 0.06, armadillo 0.04, vulture 0.04, black_stork 0.04,
#
# 0: 224x224 alp 0.53, promontory 0.12, valley 0.12, lakeside 0.05, cliff 0.04, 16.5ms
# Speed: 3.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# alp 0.53, promontory 0.12, valley 0.12, lakeside 0.05, cliff 0.04,
#
# 0: 224x224 spider_monkey 0.16, gibbon 0.08, vine_snake 0.06, kite 0.05, vulture 0.05, 17.6ms
# Speed: 3.1ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# spider_monkey 0.16, gibbon 0.08, vine_snake 0.06, kite 0.05, vulture 0.05,
#
# 0: 224x224 alp 0.44, volcano 0.34, promontory 0.10, valley 0.06, cliff 0.02, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# alp 0.44, volcano 0.34, promontory 0.10, valley 0.06, cliff 0.02,
#
# 0: 224x224 valley 0.84, alp 0.08, promontory 0.03, cliff 0.02, volcano 0.01, 17.0ms
# Speed: 4.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# valley 0.84, alp 0.08, promontory 0.03, cliff 0.02, volcano 0.01,
#
# 0: 224x224 valley 0.50, alp 0.32, maze 0.06, rapeseed 0.04, cliff 0.03, 17.9ms
# Speed: 3.0ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# valley 0.50, alp 0.32, maze 0.06, rapeseed 0.04, cliff 0.03,
#
# 0: 224x224 volcano 0.49, alp 0.23, valley 0.14, promontory 0.05, cliff 0.02, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# volcano 0.49, alp 0.23, valley 0.14, promontory 0.05, cliff 0.02,
#
# 0: 224x224 wing 0.28, airliner 0.11, nematode 0.11, parachute 0.11, warplane 0.08, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# wing 0.28, airliner 0.11, nematode 0.11, parachute 0.11, warplane 0.08,
#
# 0: 224x224 yellow_lady's_slipper 0.61, lemon 0.29, earthstar 0.03, jackfruit 0.02, ear 0.01, 18.0ms
# Speed: 3.5ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# yellow_lady's_slipper 0.61, lemon 0.29, earthstar 0.03, jackfruit 0.02, ear 0.01,
#
# 0: 224x224 yellow_lady's_slipper 0.99, sulphur_butterfly 0.00, jackfruit 0.00, lemon 0.00, plastic_bag 0.00, 19.0ms
# Speed: 2.4ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# yellow_lady's_slipper 0.99, sulphur_butterfly 0.00, jackfruit 0.00, lemon 0.00, plastic_bag 0.00,
#
# 0: 224x224 yellow_lady's_slipper 0.99, sulphur_butterfly 0.01, lemon 0.00, rapeseed 0.00, cabbage_butterfly 0.00, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# yellow_lady's_slipper 0.99, sulphur_butterfly 0.01, lemon 0.00, rapeseed 0.00, cabbage_butterfly 0.00,
#
# 0: 224x224 lakeside 0.63, ear 0.06, corn 0.02, alp 0.02, bittern 0.02, 45.5ms
# Speed: 2.0ms preprocess, 45.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lakeside 0.63, ear 0.06, corn 0.02, alp 0.02, bittern 0.02,
#
# 0: 224x224 castle 0.29, cliff 0.14, vulture 0.08, alp 0.07, promontory 0.07, 33.7ms
# Speed: 3.0ms preprocess, 33.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# castle 0.29, cliff 0.14, vulture 0.08, alp 0.07, promontory 0.07,
#
# 0: 224x224 lakeside 0.15, alp 0.09, promontory 0.09, rapeseed 0.08, maze 0.06, 33.3ms
# Speed: 3.0ms preprocess, 33.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# lakeside 0.15, alp 0.09, promontory 0.09, rapeseed 0.08, maze 0.06,
#
# 0: 224x224 ear 0.26, alp 0.25, rapeseed 0.18, lakeside 0.06, earthstar 0.03, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# ear 0.26, alp 0.25, rapeseed 0.18, lakeside 0.06, earthstar 0.03,
#
# 0: 224x224 ear 0.36, alp 0.21, rapeseed 0.15, lakeside 0.05, promontory 0.03, 17.6ms
# Speed: 3.0ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# ear 0.36, alp 0.21, rapeseed 0.15, lakeside 0.05, promontory 0.03,
#
# 0: 224x224 sloth_bear 0.19, hog 0.14, American_black_bear 0.09, brown_bear 0.08, wild_boar 0.06, 16.9ms
# Speed: 3.0ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sloth_bear 0.19, hog 0.14, American_black_bear 0.09, brown_bear 0.08, wild_boar 0.06,
#
# 0: 224x224 spider_monkey 0.30, howler_monkey 0.22, capuchin 0.08, three-toed_sloth 0.05, toucan 0.03, 16.8ms
# Speed: 3.0ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# spider_monkey 0.30, howler_monkey 0.22, capuchin 0.08, three-toed_sloth 0.05, toucan 0.03,
#
# 0: 224x224 spider_monkey 0.34, howler_monkey 0.22, capuchin 0.07, three-toed_sloth 0.05, buckeye 0.03, 17.5ms
# Speed: 3.0ms preprocess, 17.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# spider_monkey 0.34, howler_monkey 0.22, capuchin 0.07, three-toed_sloth 0.05, buckeye 0.03,
#
# 0: 224x224 megalith 0.27, hen-of-the-woods 0.12, cliff 0.03, coral_fungus 0.03, tailed_frog 0.02, 18.2ms
# Speed: 3.0ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# megalith 0.27, hen-of-the-woods 0.12, cliff 0.03, coral_fungus 0.03, tailed_frog 0.02,
#
# 0: 224x224 cliff 0.50, megalith 0.35, alp 0.05, promontory 0.03, castle 0.01, 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cliff 0.50, megalith 0.35, alp 0.05, promontory 0.03, castle 0.01,
#
# 0: 224x224 cliff 1.00, alp 0.00, promontory 0.00, unicycle 0.00, ibex 0.00, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cliff 1.00, alp 0.00, promontory 0.00, unicycle 0.00, ibex 0.00,
#
# 0: 224x224 jersey 0.43, suit 0.08, abaya 0.06, barbell 0.05, bow_tie 0.03, 17.4ms
# Speed: 3.2ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# jersey 0.43, suit 0.08, abaya 0.06, barbell 0.05, bow_tie 0.03,
#
# 0: 224x224 mongoose 0.21, mink 0.16, wood_rabbit 0.07, weasel 0.03, fox_squirrel 0.03, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mongoose 0.21, mink 0.16, wood_rabbit 0.07, weasel 0.03, fox_squirrel 0.03,
#
# 0: 224x224 stone_wall 0.69, cliff 0.31, hen-of-the-woods 0.00, promontory 0.00, alp 0.00, 17.8ms
# Speed: 4.0ms preprocess, 17.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# stone_wall 0.69, cliff 0.31, hen-of-the-woods 0.00, promontory 0.00, alp 0.00,
#
# 0: 224x224 kite 0.04, bittern 0.04, ear 0.03, American_egret 0.03, velvet 0.02, 16.6ms
# Speed: 3.6ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# kite 0.04, bittern 0.04, ear 0.03, American_egret 0.03, velvet 0.02,
#
# 0: 224x224 cliff 0.57, stone_wall 0.26, promontory 0.02, cliff_dwelling 0.01, coral_fungus 0.01, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cliff 0.57, stone_wall 0.26, promontory 0.02, cliff_dwelling 0.01, coral_fungus 0.01,
#
# 0: 224x224 cliff 0.65, pole 0.16, stone_wall 0.03, unicycle 0.03, chain_saw 0.02, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cliff 0.65, pole 0.16, stone_wall 0.03, unicycle 0.03, chain_saw 0.02,
#
# 0: 224x224 cliff 0.47, alp 0.19, stone_wall 0.07, valley 0.07, marmot 0.07, 23.2ms
# Speed: 3.3ms preprocess, 23.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cliff 0.47, alp 0.19, stone_wall 0.07, valley 0.07, marmot 0.07,
#
# 0: 224x224 valley 0.70, alp 0.23, promontory 0.03, cliff 0.01, lakeside 0.01, 17.0ms
# Speed: 2.6ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# valley 0.70, alp 0.23, promontory 0.03, cliff 0.01, lakeside 0.01,
#
# 0: 224x224 valley 0.83, alp 0.08, promontory 0.03, cliff 0.02, lakeside 0.01, 18.4ms
# Speed: 2.8ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# valley 0.83, alp 0.08, promontory 0.03, cliff 0.02, lakeside 0.01,
#
# 0: 224x224 valley 0.53, alp 0.31, promontory 0.07, lakeside 0.01, cliff 0.01, 16.5ms
# Speed: 3.3ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# valley 0.53, alp 0.31, promontory 0.07, lakeside 0.01, cliff 0.01,
#
# 0: 224x224 valley 0.65, promontory 0.10, cliff 0.07, lakeside 0.07, alp 0.03, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# valley 0.65, promontory 0.10, cliff 0.07, lakeside 0.07, alp 0.03,
#
# 0: 224x224 pay-phone 0.50, picket_fence 0.06, street_sign 0.05, cash_machine 0.04, barbershop 0.04, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# pay-phone 0.50, picket_fence 0.06, street_sign 0.05, cash_machine 0.04, barbershop 0.04,
#
# 0: 224x224 birdhouse 0.77, thatch 0.07, chime 0.03, vulture 0.02, pedestal 0.02, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# birdhouse 0.77, thatch 0.07, chime 0.03, vulture 0.02, pedestal 0.02,
#
# 0: 224x224 mobile_home 0.72, picket_fence 0.10, pay-phone 0.04, patio 0.03, chime 0.02, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mobile_home 0.72, picket_fence 0.10, pay-phone 0.04, patio 0.03, chime 0.02,
#
# 0: 224x224 worm_fence 0.58, picket_fence 0.40, patio 0.01, mobile_home 0.00, thatch 0.00, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# worm_fence 0.58, picket_fence 0.40, patio 0.01, mobile_home 0.00, thatch 0.00,
#
# 0: 224x224 picket_fence 0.89, worm_fence 0.06, patio 0.02, mobile_home 0.01, monastery 0.00, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# picket_fence 0.89, worm_fence 0.06, patio 0.02, mobile_home 0.01, monastery 0.00,
#
# 0: 224x224 birdhouse 0.34, picket_fence 0.17, chime 0.08, guillotine 0.03, pier 0.03, 17.1ms
# Speed: 3.2ms preprocess, 17.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# birdhouse 0.34, picket_fence 0.17, chime 0.08, guillotine 0.03, pier 0.03,
#
# 0: 224x224 thatch 0.13, barn 0.11, megalith 0.06, yurt 0.06, patio 0.05, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# thatch 0.13, barn 0.11, megalith 0.06, yurt 0.06, patio 0.05,
#
# 0: 224x224 tractor 0.44, lawn_mower 0.12, forklift 0.10, thresher 0.08, mobile_home 0.04, 17.0ms
# Speed: 3.3ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# tractor 0.44, lawn_mower 0.12, forklift 0.10, thresher 0.08, mobile_home 0.04,
#
# 0: 224x224 viaduct 0.40, monastery 0.19, vault 0.10, castle 0.09, triumphal_arch 0.07, 19.6ms
# Speed: 3.0ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# viaduct 0.40, monastery 0.19, vault 0.10, castle 0.09, triumphal_arch 0.07,
#
# 0: 224x224 gazelle 0.14, valley 0.09, alp 0.09, maze 0.09, impala 0.08, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# gazelle 0.14, valley 0.09, alp 0.09, maze 0.09, impala 0.08,
#
# 0: 224x224 cliff 0.86, stone_wall 0.06, cliff_dwelling 0.02, megalith 0.01, cockroach 0.01, 32.6ms
# Speed: 3.0ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cliff 0.86, stone_wall 0.06, cliff_dwelling 0.02, megalith 0.01, cockroach 0.01,
#
# 0: 224x224 megalith 0.95, cliff 0.04, viaduct 0.01, picket_fence 0.00, worm_fence 0.00, 34.2ms
# Speed: 2.0ms preprocess, 34.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# megalith 0.95, cliff 0.04, viaduct 0.01, picket_fence 0.00, worm_fence 0.00,
#
# 0: 224x224 padlock 0.96, combination_lock 0.01, guillotine 0.01, chain_saw 0.01, hook 0.01, 32.8ms
# Speed: 3.0ms preprocess, 32.8ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# padlock 0.96, combination_lock 0.01, guillotine 0.01, chain_saw 0.01, hook 0.01,
#
# 0: 224x224 boathouse 0.41, birdhouse 0.15, picket_fence 0.08, megalith 0.05, mailbox 0.04, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# boathouse 0.41, birdhouse 0.15, picket_fence 0.08, megalith 0.05, mailbox 0.04,
#
# 0: 224x224 mailbox 0.49, birdhouse 0.13, monastery 0.09, prison 0.06, vault 0.05, 18.9ms
# Speed: 3.1ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# mailbox 0.49, birdhouse 0.13, monastery 0.09, prison 0.06, vault 0.05,
#
# 0: 224x224 megalith 0.30, stone_wall 0.15, guillotine 0.09, prison 0.07, sloth_bear 0.05, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# megalith 0.30, stone_wall 0.15, guillotine 0.09, prison 0.07, sloth_bear 0.05,
#
# 0: 224x224 cabbage_butterfly 0.21, pot 0.19, picket_fence 0.11, greenhouse 0.10, daisy 0.06, 16.0ms
# Speed: 2.9ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# cabbage_butterfly 0.21, pot 0.19, picket_fence 0.11, greenhouse 0.10, daisy 0.06,

# %% [markdown]
# # Convert videos for preview with FFMPEG

# %%
import subprocess

def transcode_video(input_file, output_file, width=None, height=None, bitrate=None):
    # Create the base ffmpeg command
    cmd = ['ffmpeg', '-i', input_file]
    
    # Add video scaling if width and height are provided
    if width and height:
        cmd.extend(['-vf', f'scale={width}:{height}'])
    
    # Add video bitrate if provided
    if bitrate:
        cmd.extend(['-b:v', bitrate])
    
    # Add the output file
    cmd.append(output_file)
    
    # Execute the command
    try:
        subprocess.run(cmd, check=True)
        print(f"Transcoding completed successfully. Output file: {output_file}")
    except subprocess.CalledProcessError as e:
        print(f"An error occurred: {e}")




video_name = "00100"
video_dir = posixpath.join(V3C1_DIR, video_name)

video_mp4_path = posixpath.join(video_dir, f"{video_name}.mp4")
video_mov_path = posixpath.join(video_dir, f"{video_name}.mov")
if posixpath.isfile(video_mp4_path):
    input_video = video_mp4_path
elif posixpath.isfile(video_mov_path):
    input_video = video_mov_path
else:
    raise FileNotFoundError(f"Neither .mp4 nor .mov video file exists for {video_name}.")

output_video = posixpath.join(video_dir, f"{video_name}_preview.mp4")
new_width = 640
new_height = 360
# new_bitrate = '500k'
transcode_video(input_video, output_video, new_width, new_height)

# videos = get_all_videos(V3C1_DIR)
# for video in videos:
#     transcode_video(input_video, output_video, new_width, new_height)
# Out:
# Transcoding completed successfully. Output file: A:/IVADL/V3C1-100/00100/00100_preview.mp4
